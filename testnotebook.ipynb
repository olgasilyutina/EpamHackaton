# %%
pref = "data/NLP_dataset_final/"

# %%
tags = pref + "Tags.csv"

# %%
import pandas as pd

tags_df = pd.read_csv(tags)

# %%
# Out:
#            Count  ExcerptPostId        Id                       TagName  \
# 0       257092.0      3624959.0       1.0                          .net
# 1       683981.0      3673183.0       2.0                          html
# 2      1457944.0      3624960.0       3.0                    javascript
# 3       490198.0      3644670.0       4.0                           css
# 4      1114030.0      3624936.0       5.0                           php
# 5       257777.0      3624961.0       8.0                             c
# 6      1129802.0      3624962.0       9.0                            c#
# 7       529933.0      3624963.0      10.0                           c++
# 8       186002.0      3624964.0      12.0                          ruby
# 9         5160.0      3656743.0      14.0                          lisp
# 10      806788.0      3624965.0      16.0                        python
# 11     1303993.0      3624966.0      17.0                          java
# 12      173693.0      3624967.0      18.0                         regex
# 13      162578.0      3624968.0      19.0                           xml
# 14      480774.0      3624969.0      21.0                         mysql
# 15      402723.0      3625226.0      22.0                           sql
# 16       46634.0      4777787.0      23.0                          tsql
# 17          60.0      8355939.0      26.0                            j#
# 18       19856.0      5388160.0      27.0                       browser
# 19       65729.0      4890031.0      28.0                          linq
# 20      130769.0      4973766.0      30.0                      database
# 21        7694.0      5197182.0      33.0             language-agnostic
# 22       36035.0      4957075.0      34.0                          unix
# 23       48893.0      5253586.0      35.0                       sockets
# 24       24400.0      3625227.0      38.0                          flex
# 25        8146.0      4915464.0      40.0                         table
# 26      112669.0      3625228.0      41.0                        vb.net
# 27        1620.0      5007962.0      44.0                  structuremap
# 28           9.0     25220551.0      46.0                       alt.net
# 29       12271.0      4083816.0      48.0                  architecture
# ...          ...            ...       ...                           ...
# 49971        1.0            NaN  128209.0              pretty-checkable
# 49972        1.0     45872515.0  128211.0                    rx-kotlin2
# 49973        1.0            NaN  128212.0                       sql2016
# 49974        1.0            NaN  128213.0                   module-info
# 49975        1.0            NaN  128214.0             intellij-idea2017
# 49976        1.0            NaN  128215.0                          stjs
# 49977        1.0     45880364.0  128217.0                  amazon-agcod
# 49978        1.0            NaN  128218.0                       bincode
# 49979        1.0            NaN  128219.0                 sodiumdioxide
# 49980        1.0            NaN  128220.0                       recoder
# 49981        1.0            NaN  128221.0           macos-app-extension
# 49982        1.0     45883101.0  128222.0                    mdboostrap
# 49983        1.0            NaN  128224.0                  new-modifier
# 49984        1.0            NaN  128225.0                     navparams
# 49985        1.0            NaN  128226.0            pandas.excelwriter
# 49986        1.0            NaN  128227.0         collectionitemchanged
# 49987        1.0            NaN  128229.0                     techan.js
# 49988        1.0     45890500.0  128231.0  terraform-provider-openstack
# 49989        1.0     45890511.0  128232.0      terraform-provider-azure
# 49990        1.0     45891019.0  128233.0                      anime.js
# 49991        1.0            NaN  128234.0       markov-decision-process
# 49992        1.0            NaN  128235.0               value-iteration
# 49993        1.0            NaN  128236.0                 promise-queue
# 49994        1.0            NaN  128237.0               java-directives
# 49995        1.0            NaN  128238.0         activity-oncreateview
# 49996        1.0     45900848.0  128239.0            platypus-optimizer
# 49997        1.0     45901045.0  128240.0                       jsonnet
# 49998        1.0            NaN  128241.0          vue-slider-component
# 49999        2.0            NaN  128242.0   visual-studio-customization
# 50000        NaN            NaN       NaN                           NaN
#
#        WikiPostId
# 0       3607476.0
# 1       3673182.0
# 2       3607052.0
# 3       3644669.0
# 4       3607050.0
# 5       3607013.0
# 6       3607007.0
# 7       3606997.0
# 8       3607043.0
# 9       3656742.0
# 10      3607014.0
# 11      3607018.0
# 12      3607017.0
# 13      3607588.0
# 14      3607033.0
# 15      3607304.0
# 16      4777786.0
# 17      8355938.0
# 18      5388159.0
# 19      4890030.0
# 20      4973765.0
# 21      5197181.0
# 22      4957074.0
# 23      5253585.0
# 24      3608598.0
# 25      4915463.0
# 26      3607042.0
# 27      5007961.0
# 28     25220550.0
# 29      4083815.0
# ...           ...
# 49971         NaN
# 49972  45872514.0
# 49973         NaN
# 49974         NaN
# 49975         NaN
# 49976         NaN
# 49977  45880363.0
# 49978         NaN
# 49979         NaN
# 49980         NaN
# 49981         NaN
# 49982  45883100.0
# 49983         NaN
# 49984         NaN
# 49985         NaN
# 49986         NaN
# 49987         NaN
# 49988  45890499.0
# 49989  45890510.0
# 49990  45891018.0
# 49991         NaN
# 49992         NaN
# 49993         NaN
# 49994         NaN
# 49995         NaN
# 49996  45900847.0
# 49997  45901044.0
# 49998         NaN
# 49999         NaN
# 50000         NaN
#
# [50001 rows x 5 columns]

# %%
courses_links_csv = pref + "courses_links.csv"
qid_to_courseid_csv = pref + "question_to_course.csv"

# %%
courses_links_df = pd.read_csv(courses_links_csv)
qid_to_courseid_df = pd.read_csv(qid_to_courseid_csv)

# %%
courses_links_df
# Out:
#    id                                             course
# 0   0  https://www.coursera.org/learn/vvedenie-mashin...
# 1   1  https://www.coursera.org/learn/data-structures...
# 2   2  https://www.coursera.org/specializations/deep-...
# 3   3  https://www.coursera.org/specializations/jhu-d...

# %%
qid_to_courseid_df
# Out:
#    question  course
# 0         0       0
# 1         1       1
# 2         2       2
# 3         3       3

# %%
def c_link_by_qid(qid):
    courseid = int(qid_to_courseid_df.loc[qid_to_courseid_df['question'] == qid]['course'])
    courselink = str(courses_links_df.loc[courses_links_df['id'] == courseid]['course'])
    return courselink

# %%
courses_links_csv = pref + "courses_links.csv"
qid_to_courseid_csv = pref + "question_to_course.csv"
courses_links_df = pd.read_csv(courses_links_csv)
qid_to_courseid_df = pd.read_csv(qid_to_courseid_csv)
def c_link_by_qid(qid):
    courseid = int(qid_to_courseid_df.loc[qid_to_courseid_df['question'] == qid]['course'])
    courselink = str(courses_links_df.loc[courses_links_df['id'] == courseid]['course'][1])
    return courselink
	
c_link_by_qid(1)
# Out:
# 'https://www.coursera.org/learn/data-structures/home/welcome'

# %%
import random
import pandas as pd
pref = "data/NLP_dataset_final/"
courses_links_csv = pref + "courses_links.csv"
qid_to_courseid_csv = pref + "question_to_course.csv"
courses_links_df = pd.read_csv(courses_links_csv)
qid_to_courseid_df = pd.read_csv(qid_to_courseid_csv)

def c_link_by_qid(qid):
    courseid = int(qid_to_courseid_df.loc[qid_to_courseid_df['question'] == qid]['course'])
    courselink = str(courses_links_df.loc[courses_links_df['id'] == courseid]['course'][1])
    return courselink

from telegram.ext import Updater
updater = Updater(token='424268636:AAECue4wGOmY5VQm40DCe5ZC7ENzGmuMGHU')
def start(bot, update):
    bot.send_message(chat_id=update.message.chat_id, text=c_link_by_qid(random.choice([0, 1, 2, 3])))
dispatcher = updater.dispatcher
import logging
logging.basicConfig(format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
                level=logging.INFO)
from telegram.ext import CommandHandler
start_handler = CommandHandler('start', start)
dispatcher.add_handler(start_handler)
updater.start_polling()
# Out:
# 2017-12-02 13:27:21,766 - telegram.ext.dispatcher - ERROR - An uncaught error was raised while processing the update
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telegram\ext\dispatcher.py", line 270, in process_update
#     handler.handle_update(update, self)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telegram\ext\commandhandler.py", line 171, in handle_update
#     return self.callback(dispatcher.bot, update, **optional_args)
#   File "<ipython-input-3-3fe2c0e9de77>", line 17, in start
#     bot.send_message(chat_id=update.message.chat_id, text=c_link_by_qid(random.choice([0, 1, 2, 3])))
#   File "<ipython-input-3-3fe2c0e9de77>", line 11, in c_link_by_qid
#     courselink = str(courses_links_df.loc[courses_links_df['id'] == courseid]['course'][1])
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line 603, in __getitem__
#     result = self.index.get_value(self, key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\indexes\base.py", line 2169, in get_value
#     tz=getattr(series.dtype, 'tz', None))
#   File "pandas\index.pyx", line 98, in pandas.index.IndexEngine.get_value (pandas\index.c:3557)
#   File "pandas\index.pyx", line 106, in pandas.index.IndexEngine.get_value (pandas\index.c:3240)
#   File "pandas\index.pyx", line 154, in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)
#   File "pandas\src\hashtable_class_helper.pxi", line 404, in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:8564)
#   File "pandas\src\hashtable_class_helper.pxi", line 410, in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:8508)
# KeyError: 1

# %%
import random
import pandas as pd
pref = "data/NLP_dataset_final/"
courses_links_csv = pref + "courses_links.csv"
qid_to_courseid_csv = pref + "question_to_course.csv"

def c_link_by_qid(_qid):
    courseid = ""
    with open(qid_to_courseid_csv) as qid_to_courseid_df:
        for line in qid_to_courseid_df.readlines():
            qid, cid = line.split(",")
            if (qid == str(_qid)):
                courseid = cid
    courseid = courseid.strip()
    link = ""
    with open(courses_links_csv) as courses_links_df:
        for line in courses_links_df.readlines():
            cid, lnk = line.split(",")
            if (cid == str(courseid)):
                link = lnk
    return link.strip()
# Out:
# 'https://www.coursera.org/learn/data-structures/home/welcome'

# %%
5
# Out:
# 5

# %%
import random
import pandas as pd
def get_qid(solink):
    return solink.split("/")[4]
pref = "data/NLP_dataset_final/"
courses_links_csv = pref + "courses_links.csv"
qid_to_courseid_csv = pref + "question_to_course.csv"

def c_link_by_qid(solink):
    _qid = get_qid(solink)
    courseid = ""
    with open(qid_to_courseid_csv) as qid_to_courseid_df:
        for line in qid_to_courseid_df.readlines():
            qid, cid = line.split(",")
            if (qid == str(_qid)):
                courseid = cid
    courseid = courseid.strip()
    link = ""
    with open(courses_links_csv) as courses_links_df:
        for line in courses_links_df.readlines():
            cid, lnk = line.split(",")
            if (cid == str(courseid)):
                link = lnk
    return link.strip()

from telegram.ext import Updater
updater = Updater(token='424268636:AAECue4wGOmY5VQm40DCe5ZC7ENzGmuMGHU')
def start(bot, update):
    res = "examples\n"
    with open(qid_to_courseid_csv) as qid_to_courseid_df:
        for line in qid_to_courseid_df.readlines():
            qid, cid = line.split(",")
            res += "https://stackoverflow.com/questions/" + qid + '\n'
    bot.send_message(chat_id=update.message.chat_id, text=res)
dispatcher = updater.dispatcher
import logging
logging.basicConfig(format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
                level=logging.INFO)
from telegram.ext import CommandHandler
start_handler = CommandHandler('start', start)
dispatcher.add_handler(start_handler)

def echo(bot, update):
    print('here')
    bot.send_message(chat_id=update.message.chat_id, text=c_link_by_qid(update.message.text))
from telegram.ext import MessageHandler, Filters
echo_handler = MessageHandler(Filters.text, echo)
dispatcher.add_handler(echo_handler)

updater.start_polling()

# %%
def get_qid(solink):
    return solink.split("/")[4]
get_qid("https://stackoverflow.com/questions/29623171/simple-prediction-using-linear-regression-with-python")
# Out:
# '29623171'

# %%
from telegram.ext import Updater
